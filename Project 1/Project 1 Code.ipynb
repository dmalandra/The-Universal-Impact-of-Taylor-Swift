# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import scipy.stats as st
from scipy.stats import linregress

# %%
# Read in csv
csv_path = Path("spotify-2023.csv")

top_spotify = pd.read_csv(csv_path)
top_spotify

top_spotify_df = pd.DataFrame(top_spotify)
top_spotify_df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [953 rows x 24 columns]

# %%
# Drop null values
clean_spotify_df = top_spotify_df.dropna()
clean_spotify_df = clean_spotify_df.drop([574])
clean_spotify_df["streams"] = clean_spotify_df["streams"].astype(int)
clean_spotify_df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [816 rows x 24 columns]

# %%
# Groupby number of streams

spotify_streams_df = clean_spotify_df.set_index("streams")
spotify_streams_ranked = spotify_streams_df.sort_values("streams", ascending=False)
spotify_streams_ranked
# Out:
#                                                track_name  \
# streams
# 3562543890                                   Shape of You
# 2808096550  Sunflower - Spider-Man: Into the Spider-Verse
# 2713922350                                      One Dance
# 2665343922                      STAY (with Justin Bieber)
# 2594040133                                       Believer
# ...                                                   ...
# 22581161                                             Rush
# 14780425                                        Overdrive
# 11956641                      Gol Bolinha, Gol Quadrado 2
# 1365184                                 Jhoome Jo Pathaan
# 2762                                          Que Vuelvas
#
#                                                artist(s)_name  artist_count  \
# streams
# 3562543890                                         Ed Sheeran             1
# 2808096550                              Post Malone, Swae Lee             2
# 2713922350                                Drake, WizKid, Kyla             3
# 2665343922                       Justin Bieber, The Kid Laroi             2
# 2594040133                                    Imagine Dragons             1
# ...                                                       ...           ...
# 22581161                                          Troye Sivan             1
# 14780425                                          Post Malone             1
# 11956641                                  Mc Pedrinho, DJ 900             2
# 1365184     Arijit Singh, Vishal Dadlani, Sukriti Kakar, V...             6
# 2762                               Carin Leon, Grupo Frontera             2
#
#             released_year  released_month  released_day  in_spotify_playlists  \
# streams
# 3562543890           2017               1             6                 32181
# 2808096550           2018              10             9                 24094
# 2713922350           2016               4             4                 43257
# 2665343922           2021               7             9                 17050
# 2594040133           2017               1            31                 18986
# ...                   ...             ...           ...                   ...
# 22581161             2023               7            13                   864
# 14780425             2023               7            14                   410
# 11956641             2023               6             1                   293
# 1365184              2022              12            22                   138
# 2762                 2022              12             9                   763
#
#             in_spotify_charts  in_apple_playlists  in_apple_charts  ...  bpm  \
# streams                                                             ...
# 3562543890                 10                  33                0  ...   96
# 2808096550                 78                 372              117  ...   90
# 2713922350                 24                 433              107  ...  104
# 2665343922                 36                 492               99  ...  170
# 2594040133                 23                 250              121  ...  125
# ...                       ...                 ...              ...  ...  ...
# 22581161                   78                  71              135  ...  126
# 14780425                   36                  36               32  ...  140
# 11956641                    8                   5                2  ...  133
# 1365184                     4                  13               78  ...  105
# 2762                       26                  21              110  ...  162
#
#             key   mode  danceability_% valence_% energy_%  acousticness_%  \
# streams
# 3562543890   C#  Minor              83        93       65              58
# 2808096550    D  Major              76        91       50              54
# 2713922350   C#  Major              77        36       63               1
# 2665343922   C#  Major              59        48       76               4
# 2594040133   A#  Minor              77        74       78               4
# ...         ...    ...             ...       ...      ...             ...
# 22581161      F  Minor              74        35       84               0
# 14780425     C#  Major              56        48       73               0
# 11956641      B  Minor              93        68       65              42
# 1365184       G  Major              82        62       74              10
# 2762         A#  Major              49        78       64              19
#
#             instrumentalness_%  liveness_%  speechiness_%
# streams
# 3562543890                   0           9              8
# 2808096550                   0           7              5
# 2713922350                   0          36              5
# 2665343922                   0          10              5
# 2594040133                   0          23             11
# ...                        ...         ...            ...
# 22581161                     0          11              6
# 14780425                     0          35              4
# 11956641                     0          12             25
# 1365184                      0          33              7
# 2762                         0          11              4
#
# [816 rows x 23 columns]

# %%
# Only filter by songs released in 2023

top_streams_2023 = spotify_streams_df[(spotify_streams_df["released_year"] == 2023)]
top_streams_2023_ranked = top_streams_2023.sort_values("streams", ascending=False)
top_streams_2023_ranked
# Out:
#                                       track_name              artist(s)_name  \
# streams
# 725980112                        Ella Baila Sola  Eslabon Armado, Peso Pluma
# 721975598  Shakira: Bzrp Music Sessions, Vol. 53           Shakira, Bizarrap
# 618990393                                    TQG            Karol G, Shakira
# 553634067                        La Bebe - Remix       Peso Pluma, Yng Lvcas
# 518745108                    Die For You - Remix   Ariana Grande, The Weeknd
# ...                                          ...                         ...
# 29562220                               New Jeans                    NewJeans
# 24975653          Danger (Spider) (Offset & JID)                 Offset, JID
# 22581161                                    Rush                 Troye Sivan
# 14780425                               Overdrive                 Post Malone
# 11956641             Gol Bolinha, Gol Quadrado 2         Mc Pedrinho, DJ 900
#
#            artist_count  released_year  released_month  released_day  \
# streams
# 725980112             2           2023               3            16
# 721975598             2           2023               1            11
# 618990393             2           2023               2            23
# 553634067             2           2023               3            17
# 518745108             2           2023               2            24
# ...                 ...            ...             ...           ...
# 29562220              1           2023               7             7
# 24975653              2           2023               6             2
# 22581161              1           2023               7            13
# 14780425              1           2023               7            14
# 11956641              2           2023               6             1
#
#            in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# streams
# 725980112                  3090                 50                  34
# 721975598                  5724                 44                 119
# 618990393                  4284                 49                 115
# 553634067                  2953                 44                  49
# 518745108                  3408                 47                  87
# ...                         ...                ...                 ...
# 29562220                     77                 35                   8
# 24975653                    214                  0                   3
# 22581161                    864                 78                  71
# 14780425                    410                 36                  36
# 11956641                    293                  8                   5
#
#            in_apple_charts  ...  bpm  key   mode  danceability_% valence_%  \
# streams                     ...
# 725980112              222  ...  148    F  Minor              67        83
# 721975598              108  ...  122    D  Minor              78        50
# 618990393              123  ...  180    E  Minor              72        61
# 553634067              110  ...  170    D  Minor              81        56
# 518745108               86  ...   67   C#  Minor              53        50
# ...                    ...  ...  ...  ...    ...             ...       ...
# 29562220               166  ...  134    E  Minor              81        53
# 24975653                 3  ...  143    B  Major              83        25
# 22581161               135  ...  126    F  Minor              74        35
# 14780425                32  ...  140   C#  Major              56        48
# 11956641                 2  ...  133    B  Minor              93        68
#
#           energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# streams
# 725980112       76              48                   0           8
# 721975598       63              27                   0           9
# 618990393       63              67                   0           9
# 553634067       48              21                   0           8
# 518745108       53              23                   0          44
# ...            ...             ...                 ...         ...
# 29562220        72              51                   0          12
# 24975653        69               4                   0          23
# 22581161        84               0                   0          11
# 14780425        73               0                   0          35
# 11956641        65              42                   0          12
#
#            speechiness_%
# streams
# 725980112              3
# 721975598              5
# 618990393             28
# 553634067             33
# 518745108              7
# ...                  ...
# 29562220               5
# 24975653              12
# 22581161               6
# 14780425               4
# 11956641              25
#
# [159 rows x 23 columns]

# %%
# Plot total streams by release month
x_axis = top_streams_2023_ranked['released_month']
y_axis = top_streams_2023_ranked.index
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

correlation = st.pearsonr(x_axis, y_axis)

print(f"The r-value is: {round(correlation[0],2)}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")

plt.title('Total Artist Streams Relative to Month of Release 2023')
plt.xlabel('Month of Song Release')
plt.ylabel('Total Streams on Spotify in 2023')
plt.savefig("output_data/streams_x_month.png")
plt.show()
# Out:
# The r-value is: -0.51

# %%
# Trial scatterplot with 2 likely correlated key features (bpm and danceability)
x_axis = top_streams_2023_ranked['bpm']
y_axis = top_streams_2023_ranked["danceability_%"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

correlation = st.pearsonr(x_axis, y_axis)

print(f"The r-value is: {round(correlation[0],2)}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")

plt.title('Danceability % vs. Beats Per Minute Song Cadence')
plt.xlabel('BPM')
plt.ylabel('Danceability %')
plt.savefig("output_data/dance_x_bpm.png")
plt.show()
# Out:
# The r-value is: -0.09

# %%
# Streams by valence % (positivity of musical content)
x_axis = top_streams_2023_ranked["valence_%"]
y_axis = top_streams_2023_ranked.index
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

correlation = st.pearsonr(x_axis, y_axis)

print(f"The r-value is: {round(correlation[0],2)}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")

plt.title('Total Streams in Relation to Valence % (Positivity)')
plt.xlabel('Valence %')
plt.ylabel('Streams')
plt.savefig("output_data/streams_x_positivity.png")
plt.show()
# Out:
# The r-value is: 0.14

# %%
# Popularity by song key??
x_axis = top_streams_2023_ranked["energy_%"]
y_axis = top_streams_2023_ranked.index
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

correlation = st.pearsonr(x_axis, y_axis)

print(f"The r-value is: {round(correlation[0],2)}")
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")

plt.title('Total Streams by Energy Level of Song')
plt.xlabel('Energy %')
plt.ylabel('Streams')
plt.savefig("output_data/streams_x_energy.png")
plt.show()
# Out:
# The r-value is: -0.04

# %%
# Import Alaina's streaming CSV
csv_path2 = Path("2023 Spotify Data.csv")

spotify_data_2023 = pd.read_csv(csv_path2)
spotify_data_2023

spotify_data_2023_df = pd.DataFrame(spotify_data_2023)

del spotify_data_2023_df["uri"]
spotify_data_2023_df
# Out:
#          week  rank                         artist_names  \
# 0     2023.01     1                                  SZA
# 1     2023.01     2                     Drake, 21 Savage
# 2     2023.01     3  Metro Boomin, The Weeknd, 21 Savage
# 3     2023.01     4                         Taylor Swift
# 4     2023.01     5                         Lil Uzi Vert
# ...       ...   ...                                  ...
# 9195  2023.44   196                        Michael Bublé
# 9196  2023.44   197                        Morgan Wallen
# 9197  2023.44   198                      Lil Baby, Drake
# 9198  2023.44   199                         Taylor Swift
# 9199  2023.44   200            PinkPantheress, Ice Spice
#
#                                        track_name  \
# 0                                       Kill Bill
# 1                                       Rich Flex
# 2          Creepin' (with The Weeknd & 21 Savage)
# 3                                       Anti-Hero
# 4                                 Just Wanna Rock
# ...                                           ...
# 9195  It's Beginning to Look a Lot like Christmas
# 9196                                  Chasin' You
# 9197                                   Yes Indeed
# 9198                                  Blank Space
# 9199                           Boy's a liar Pt. 2
#
#                                   source  peak_rank  previous_rank  \
# 0     Top Dawg Entertainment/RCA Records          1              2
# 1                 OVO / Republic Records          1             13
# 2                       Republic Records          1             12
# 3                           Taylor Swift          1             26
# 4                Generation Now/Atlantic          5             21
# ...                                  ...        ...            ...
# 9195                             Reprise          7             -1
# 9196                    Big Loud Records         55             -1
# 9197          Quality Control Music, LLC          2             -1
# 9198            Big Machine Records, LLC         34            127
# 9199                      Warner Records          1            185
#
#       weeks_on_chart   streams
# 0                  4  15030938
# 1                  9   8469115
# 2                  5   8039812
# 3                 11   6821345
# 4                 12   6709165
# ...              ...       ...
# 9195              41   2121166
# 9196             140   2117578
# 9197             167   2108074
# 9198              37   2102969
# 9199              40   2101312
#
# [9200 rows x 9 columns]

# %%
# Index by track name

track_name = spotify_data_2023_df.set_index("track_name")
track_name_sorted = track_name.sort_values("streams", ascending=False)
track_name_sorted
# Out:
#                                                        week  rank  \
# track_name
# Flowers                                             2023.04     1
# Flowers                                             2023.03     1
# Is It Over Now? (Taylor's Version) (From The Va...  2023.43     1
# vampire                                             2023.27     1
# vampire                                             2023.28     1
# ...                                                     ...   ...
# Chamber Of Reflection                               2023.01   196
# Ni**as In Paris                                     2023.01   197
# Buy Dirt                                            2023.01   198
# The Night We Met                                    2023.01   199
# Not Allowed                                         2023.01   200
#
#                                                                 artist_names  \
# track_name
# Flowers                                                          Miley Cyrus
# Flowers                                                          Miley Cyrus
# Is It Over Now? (Taylor's Version) (From The Va...              Taylor Swift
# vampire                                                       Olivia Rodrigo
# vampire                                                       Olivia Rodrigo
# ...                                                                      ...
# Chamber Of Reflection                                            Mac DeMarco
# Ni**as In Paris                                            JAY-Z, Kanye West
# Buy Dirt                                            Jordan Davis, Luke Bryan
# The Night We Met                                                  Lord Huron
# Not Allowed                                                          TV Girl
#
#                                                                       source  \
# track_name
# Flowers                                                             Columbia
# Flowers                                                             Columbia
# Is It Over Now? (Taylor's Version) (From The Va...              Taylor Swift
# vampire                                                    Olivia Rodrigo PS
# vampire                                                    Olivia Rodrigo PS
# ...                                                                      ...
# Chamber Of Reflection                                        Captured Tracks
# Ni**as In Paris                                     Roc Nation/RocAFella/IDJ
# Buy Dirt                                                       MCA Nashville
# The Night We Met                                                    IAMSOUND
# Not Allowed                                                          TV Girl
#
#                                                     peak_rank  previous_rank  \
# track_name
# Flowers                                                     1              1
# Flowers                                                     1             -1
# Is It Over Now? (Taylor's Version) (From The Va...          1             -1
# vampire                                                     1             -1
# vampire                                                     1             -1
# ...                                                       ...            ...
# Chamber Of Reflection                                     196             -1
# Ni**as In Paris                                           107             -1
# Buy Dirt                                                   67             -1
# The Night We Met                                           48             -1
# Not Allowed                                               150             -1
#
#                                                     weeks_on_chart   streams
# track_name
# Flowers                                                          2  21784758
# Flowers                                                          1  20849005
# Is It Over Now? (Taylor's Version) (From The Va...               1  20062285
# vampire                                                          1  18614248
# vampire                                                          1  18614248
# ...                                                            ...       ...
# Chamber Of Reflection                                            1   1767184
# Ni**as In Paris                                                 51   1764826
# Buy Dirt                                                        64   1764496
# The Night We Met                                                64   1759621
# Not Allowed                                                     12   1759126
#
# [9200 rows x 8 columns]

# %%
# Index by artist name
artist_name = spotify_data_2023_df.set_index("artist_names")
artist_name_sorted = artist_name.sort_values("streams", ascending=False)
artist_name_sorted
# Out:
#                              week  rank  \
# artist_names
# Miley Cyrus               2023.04     1
# Miley Cyrus               2023.03     1
# Taylor Swift              2023.43     1
# Olivia Rodrigo            2023.27     1
# Olivia Rodrigo            2023.28     1
# ...                           ...   ...
# Mac DeMarco               2023.01   196
# JAY-Z, Kanye West         2023.01   197
# Jordan Davis, Luke Bryan  2023.01   198
# Lord Huron                2023.01   199
# TV Girl                   2023.01   200
#
#                                                                  track_name  \
# artist_names
# Miley Cyrus                                                         Flowers
# Miley Cyrus                                                         Flowers
# Taylor Swift              Is It Over Now? (Taylor's Version) (From The V...
# Olivia Rodrigo                                                      vampire
# Olivia Rodrigo                                                      vampire
# ...                                                                     ...
# Mac DeMarco                                           Chamber Of Reflection
# JAY-Z, Kanye West                                           Ni**as In Paris
# Jordan Davis, Luke Bryan                                           Buy Dirt
# Lord Huron                                                 The Night We Met
# TV Girl                                                         Not Allowed
#
#                                             source  peak_rank  previous_rank  \
# artist_names
# Miley Cyrus                               Columbia          1              1
# Miley Cyrus                               Columbia          1             -1
# Taylor Swift                          Taylor Swift          1             -1
# Olivia Rodrigo                   Olivia Rodrigo PS          1             -1
# Olivia Rodrigo                   Olivia Rodrigo PS          1             -1
# ...                                            ...        ...            ...
# Mac DeMarco                        Captured Tracks        196             -1
# JAY-Z, Kanye West         Roc Nation/RocAFella/IDJ        107             -1
# Jordan Davis, Luke Bryan             MCA Nashville         67             -1
# Lord Huron                                IAMSOUND         48             -1
# TV Girl                                    TV Girl        150             -1
#
#                           weeks_on_chart   streams
# artist_names
# Miley Cyrus                            2  21784758
# Miley Cyrus                            1  20849005
# Taylor Swift                           1  20062285
# Olivia Rodrigo                         1  18614248
# Olivia Rodrigo                         1  18614248
# ...                                  ...       ...
# Mac DeMarco                            1   1767184
# JAY-Z, Kanye West                     51   1764826
# Jordan Davis, Luke Bryan              64   1764496
# Lord Huron                            64   1759621
# TV Girl                               12   1759126
#
# [9200 rows x 8 columns]

# %%
total_streams_2023 = spotify_data_2023_df.groupby(['track_name', 'artist_names'])['streams'].sum()
total_streams_2023
total_streams_2023_df = pd.DataFrame(total_streams_2023)
total_streams_2023_df

total_streams_2023_df_sorted = total_streams_2023_df.sort_values('streams', ascending=False)
total_streams_2023_df_sorted
# Out:
#                                                             streams
# track_name                  artist_names
# Last Night                  Morgan Wallen                 414584348
# Kill Bill                   SZA                           388686470
# Ella Baila Sola             Eslabon Armado, Peso Pluma    267965608
# Flowers                     Miley Cyrus                   263735971
# Boy's a liar Pt. 2          PinkPantheress, Ice Spice     261903576
# ...                                                             ...
# On Wat U On (with GloRilla) Moneybagg Yo, GloRilla          1864790
# Billete Grande (En Vivo)    Fuerza Regida, Edgardo Nuñez    1853961
# Neverita                    Bad Bunny                       1837465
# Conceited                   SZA                             1824752
# Circo Loco                  Drake, 21 Savage                1782096
#
# [951 rows x 1 columns]

# %%
# Compare artists from this DataFrame to original spotify-2023.csv

spotify_data_2023_df = spotify_data_2023_df.rename(columns={"artist_names": "Artist", "track_name": "Track Title", "streams": "Total Streams"})
spotify_data_2023_df
# Out:
#          week  rank                               Artist  \
# 0     2023.01     1                                  SZA
# 1     2023.01     2                     Drake, 21 Savage
# 2     2023.01     3  Metro Boomin, The Weeknd, 21 Savage
# 3     2023.01     4                         Taylor Swift
# 4     2023.01     5                         Lil Uzi Vert
# ...       ...   ...                                  ...
# 9195  2023.44   196                        Michael Bublé
# 9196  2023.44   197                        Morgan Wallen
# 9197  2023.44   198                      Lil Baby, Drake
# 9198  2023.44   199                         Taylor Swift
# 9199  2023.44   200            PinkPantheress, Ice Spice
#
#                                       Track Title  \
# 0                                       Kill Bill
# 1                                       Rich Flex
# 2          Creepin' (with The Weeknd & 21 Savage)
# 3                                       Anti-Hero
# 4                                 Just Wanna Rock
# ...                                           ...
# 9195  It's Beginning to Look a Lot like Christmas
# 9196                                  Chasin' You
# 9197                                   Yes Indeed
# 9198                                  Blank Space
# 9199                           Boy's a liar Pt. 2
#
#                                   source  peak_rank  previous_rank  \
# 0     Top Dawg Entertainment/RCA Records          1              2
# 1                 OVO / Republic Records          1             13
# 2                       Republic Records          1             12
# 3                           Taylor Swift          1             26
# 4                Generation Now/Atlantic          5             21
# ...                                  ...        ...            ...
# 9195                             Reprise          7             -1
# 9196                    Big Loud Records         55             -1
# 9197          Quality Control Music, LLC          2             -1
# 9198            Big Machine Records, LLC         34            127
# 9199                      Warner Records          1            185
#
#       weeks_on_chart  Total Streams
# 0                  4       15030938
# 1                  9        8469115
# 2                  5        8039812
# 3                 11        6821345
# 4                 12        6709165
# ...              ...            ...
# 9195              41        2121166
# 9196             140        2117578
# 9197             167        2108074
# 9198              37        2102969
# 9199              40        2101312
#
# [9200 rows x 9 columns]

# %%
clean_spotify_df = clean_spotify_df.rename(columns={"track_name": "Track Title", "artist(s)_name": "Artist", "streams": "Total Streams"})
clean_spotify_df
# Out:
#                              Track Title              Artist  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts  Total Streams  in_apple_playlists  ...  bpm key  \
# 0                  147      141381703                  43  ...  125   B
# 1                   48      133716286                  48  ...   92  C#
# 2                  113      140003974                  94  ...  138   F
# 3                  100      800840817                 116  ...  170   A
# 4                   50      303236322                  84  ...  144   A
# ..                 ...            ...                 ...  ...  ...  ..
# 948                  0       91473363                  61  ...  144   A
# 949                  0      121871870                   4  ...  166  F#
# 950                  0       73513683                   2  ...   92  C#
# 951                  0      133895612                  29  ...   97  C#
# 952                  2       96007391                  27  ...   90   E
#
#       mode danceability_%  valence_% energy_% acousticness_%  \
# 0    Major             80         89       83             31
# 1    Major             71         61       74              7
# 2    Major             51         32       53             17
# 3    Major             55         58       72             11
# 4    Minor             65         23       80             14
# ..     ...            ...        ...      ...            ...
# 948  Major             60         24       39             57
# 949  Major             42          7       24             83
# 950  Major             80         81       67              4
# 951  Major             82         67       77              8
# 952  Minor             61         32       67             15
#
#      instrumentalness_%  liveness_%  speechiness_%
# 0                     0           8              4
# 1                     0          10              4
# 2                     0          31              6
# 3                     0          11             15
# 4                    63          11              6
# ..                  ...         ...            ...
# 948                   0           8              3
# 949                   1          12              6
# 950                   0           8              6
# 951                   0          12              5
# 952                   0          11              5
#
# [816 rows x 24 columns]

# %%
clean_spotify_df_2023 = clean_spotify_df[(clean_spotify_df["released_year"] == 2023)]
clean_spotify_df_2023
# Out:
#                              Track Title                       Artist  \
# 0    Seven (feat. Latto) (Explicit Ver.)             Latto, Jung Kook
# 1                                   LALA                  Myke Towers
# 2                                vampire               Olivia Rodrigo
# 4                         WHERE SHE GOES                    Bad Bunny
# 5                               Sprinter            Dave, Central Cee
# ..                                   ...                          ...
# 370                           Love Again                The Kid Laroi
# 380                                LLYLM                     ROSALÔøΩ
# 382                            TRUSTFALL                         P!nk
# 398                             MuÔøΩÔøΩ  Steve Aoki, Tini, La Joaqui
# 404                      Sugar Rush Ride          TOMORROW X TOGETHER
#
#      artist_count  released_year  released_month  released_day  \
# 0               2           2023               7            14
# 1               1           2023               3            23
# 2               1           2023               6            30
# 4               1           2023               5            18
# 5               2           2023               6             1
# ..            ...            ...             ...           ...
# 370             1           2023               1            27
# 380             1           2023               1            27
# 382             1           2023               1            27
# 398             3           2023               1            12
# 404             1           2023               1            27
#
#      in_spotify_playlists  in_spotify_charts  Total Streams  \
# 0                     553                147      141381703
# 1                    1474                 48      133716286
# 2                    1397                113      140003974
# 4                    3133                 50      303236322
# 5                    2186                 91      183706234
# ..                    ...                ...            ...
# 370                  1283                  0      147538971
# 380                  1838                  0      124988687
# 382                  2098                 16      134255790
# 398                   658                  6      120972253
# 404                   359                  0      107642809
#
#      in_apple_playlists  ...  bpm key   mode danceability_%  valence_%  \
# 0                    43  ...  125   B  Major             80         89
# 1                    48  ...   92  C#  Major             71         61
# 2                    94  ...  138   F  Major             51         32
# 4                    84  ...  144   A  Minor             65         23
# 5                    67  ...  141  C#  Major             92         66
# ..                  ...  ...  ...  ..    ...            ...        ...
# 370                  57  ...  107   B  Minor             66         47
# 380                 105  ...  170  F#  Minor             56         56
# 382                  88  ...  122  G#  Major             64         25
# 398                  33  ...   90  A#  Minor             68         83
# 404                  12  ...  125  A#  Minor             71         83
#
#     energy_% acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 0         83             31                   0           8              4
# 1         74              7                   0          10              4
# 2         53             17                   0          31              6
# 4         80             14                  63          11              6
# 5         58             19                   0           8             24
# ..       ...            ...                 ...         ...            ...
# 370       40             72                   0          11              3
# 380       63             13                   0          19             27
# 382       89              0                   0          15              9
# 398       71              3                   0          31              8
# 404       89              1                   0          17              9
#
# [159 rows x 24 columns]

# %%
# Merge two new dataframes

final_spotify_streams_2023 = pd.merge(clean_spotify_df_2023, spotify_data_2023_df, on=["Artist", "Track Title", "Total Streams"], how="outer").reset_index()
final_spotify_streams_2023  = final_spotify_streams_2023.drop(columns=["artist_count", "released_day"])
final_spotify_streams_2023
# Out:
#       index                                  Track Title  \
# 0         0          Seven (feat. Latto) (Explicit Ver.)
# 1         1                                         LALA
# 2         2                                      vampire
# 3         3                               WHERE SHE GOES
# 4         4                                     Sprinter
# ...     ...                                          ...
# 9354   9354  It's Beginning to Look a Lot like Christmas
# 9355   9355                                  Chasin' You
# 9356   9356                                   Yes Indeed
# 9357   9357                                  Blank Space
# 9358   9358                           Boy's a liar Pt. 2
#
#                          Artist  released_year  released_month  \
# 0              Latto, Jung Kook         2023.0             7.0
# 1                   Myke Towers         2023.0             3.0
# 2                Olivia Rodrigo         2023.0             6.0
# 3                     Bad Bunny         2023.0             5.0
# 4             Dave, Central Cee         2023.0             6.0
# ...                         ...            ...             ...
# 9354              Michael Bublé            NaN             NaN
# 9355              Morgan Wallen            NaN             NaN
# 9356            Lil Baby, Drake            NaN             NaN
# 9357               Taylor Swift            NaN             NaN
# 9358  PinkPantheress, Ice Spice            NaN             NaN
#
#       in_spotify_playlists  in_spotify_charts  Total Streams  \
# 0                    553.0              147.0      141381703
# 1                   1474.0               48.0      133716286
# 2                   1397.0              113.0      140003974
# 3                   3133.0               50.0      303236322
# 4                   2186.0               91.0      183706234
# ...                    ...                ...            ...
# 9354                   NaN                NaN        2121166
# 9355                   NaN                NaN        2117578
# 9356                   NaN                NaN        2108074
# 9357                   NaN                NaN        2102969
# 9358                   NaN                NaN        2101312
#
#       in_apple_playlists  in_apple_charts  ... acousticness_%  \
# 0                   43.0            263.0  ...           31.0
# 1                   48.0            126.0  ...            7.0
# 2                   94.0            207.0  ...           17.0
# 3                   84.0            133.0  ...           14.0
# 4                   67.0            213.0  ...           19.0
# ...                  ...              ...  ...            ...
# 9354                 NaN              NaN  ...            NaN
# 9355                 NaN              NaN  ...            NaN
# 9356                 NaN              NaN  ...            NaN
# 9357                 NaN              NaN  ...            NaN
# 9358                 NaN              NaN  ...            NaN
#
#       instrumentalness_% liveness_%  speechiness_%     week   rank  \
# 0                    0.0        8.0            4.0      NaN    NaN
# 1                    0.0       10.0            4.0      NaN    NaN
# 2                    0.0       31.0            6.0      NaN    NaN
# 3                   63.0       11.0            6.0      NaN    NaN
# 4                    0.0        8.0           24.0      NaN    NaN
# ...                  ...        ...            ...      ...    ...
# 9354                 NaN        NaN            NaN  2023.44  196.0
# 9355                 NaN        NaN            NaN  2023.44  197.0
# 9356                 NaN        NaN            NaN  2023.44  198.0
# 9357                 NaN        NaN            NaN  2023.44  199.0
# 9358                 NaN        NaN            NaN  2023.44  200.0
#
#                           source  peak_rank  previous_rank  weeks_on_chart
# 0                            NaN        NaN            NaN             NaN
# 1                            NaN        NaN            NaN             NaN
# 2                            NaN        NaN            NaN             NaN
# 3                            NaN        NaN            NaN             NaN
# 4                            NaN        NaN            NaN             NaN
# ...                          ...        ...            ...             ...
# 9354                     Reprise        7.0           -1.0            41.0
# 9355            Big Loud Records       55.0           -1.0           140.0
# 9356  Quality Control Music, LLC        2.0           -1.0           167.0
# 9357    Big Machine Records, LLC       34.0          127.0            37.0
# 9358              Warner Records        1.0          185.0            40.0
#
# [9359 rows x 29 columns]
